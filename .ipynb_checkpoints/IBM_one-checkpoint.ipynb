# %%
import numpy as np
import math
from nltk.tokenize import word_tokenize
from collections import defaultdict
from nltk.translate.metrics import alignment_error_rate
from nltk.metrics.scores import (precision, recall)
from operator import itemgetter

# %%
#DATA
file = open('./train.en', 'r')
train_en = file.read()
raw_sentences_train_en = train_en.split("\n")

file = open('./train.hi', 'r')
train_hi = file.read()
raw_sentences_train_hi = train_hi.split("\n")

file = open('./test.en', 'r')
test_en = file.read()
raw_sentences_test_en = test_en.split("\n")

file = open('./test.hi', 'r')
test_hi = file.read()
raw_sentences_test_hi = test_hi.split("\n")

file = open('./dev.en.txt', 'r')
dev_en = file.read()
raw_sentences_dev_en = dev_en.split("\n")

file = open('./dev.hi', 'r')
dev_hi = file.read()
raw_sentences_dev_hi = dev_hi.split("\n")

# %%
def add_null(data):
    list_ = []
    for sentence in data:
        list_.append("NULL " + sentence)
#     print(list_[2])
    return list_

# %%
sentences_dev_hi = add_null(raw_sentences_dev_hi)
sentences_test_hi = add_null(raw_sentences_test_hi)
sentences_train_hi = add_null(raw_sentences_train_hi)

# %%
def make_lower_case(data):
    list_ = []
    for sentence in data:
        list_.append("NULL " + sentence.lower())
#     print(list_[2])
    return list_

# %%
sentences_dev_en = make_lower_case(raw_sentences_dev_en)
sentences_test_en = make_lower_case(raw_sentences_test_en)
sentences_train_en = make_lower_case(raw_sentences_train_en)

# %%
def is_converged(new, old, epoch):
    epsilone = 0.00000001
#     new = list(new.values())
#     old = list(old.values())
    
#     new_val = []
#     for (hin, ddict) in new.items():
#         for (eng, prob) in ddict.items():
#             new_val.append('{0:.8f}'.format(prob))
            
#     old_val = []
#     for (hin, ddict) in old.items():
#         for (eng, prob) in ddict.items():
#             old_val.append('{0:.8f}'.format(prob))        

#     for i in range(len(old_val)):
#         if math.fabs(float(new_val[i]) - float(old_val[i])) > epsilone: 
    if epoch < 15:
        return False
    return True

# %%
def perform_EM(en_sentences, hi_sentences):
    
    uni_ini = 0.00001
    
    translation_prob = defaultdict(lambda: float(uni_ini))
    translation_prob_prev = defaultdict(float)
    
    epoch = 0
    
    while True:

        epoch += 1
        print("epoch num:", epoch,"\n")
        count = defaultdict(float)
        total = defaultdict(float)
        s_total = defaultdict(float)
        
        for index_sen, hin_sen in enumerate(hi_sentences):
            #compute normalization
            hin_sen_words = hin_sen.split(" ")
            for hin_word in hin_sen_words:
                s_total[hin_word] = 0
                eng_sen_words = en_sentences[index_sen].split(" ")
                for eng_word in eng_sen_words:
                        s_total[hin_word] += translation_prob[(hin_word, eng_word)]
            
            #collect counts
            for hin_word in hin_sen_words:
                eng_sen_words = en_sentences[index_sen].split(" ")
                for eng_word in eng_sen_words:
                        count[(hin_word, eng_word)] += translation_prob[(hin_word, eng_word)]/s_total[hin_word]
                        total[eng_word] += translation_prob[(hin_word, eng_word)]/s_total[hin_word]                   

        #estimate probabilities
        for (hin_word, eng_word) in translation_prob.keys():
                translation_prob[(hin_word, eng_word)] = count[(hin_word, eng_word)]/total[eng_word]

        if is_converged(translation_prob, translation_prob_prev, epoch) == True:
            break
        
        translation_prob_prev = translation_prob
        
        
    return translation_prob

# %%
def train_model(sentences_train_en, sentences_train_hi):
    
    translation_prob = perform_EM(sentences_train_en, sentences_train_hi)
    return translation_prob

# %%
tef = train_model(sentences_train_en, sentences_train_hi)
# Out:
# epoch num: 1
#
# epoch num: 2
#
# epoch num: 3
#
# epoch num: 4
#
# epoch num: 5
#
# epoch num: 6
#
# epoch num: 7
#
# epoch num: 8
#
# epoch num: 9
#
# epoch num: 10
#
# epoch num: 11
#
# epoch num: 12
#
# epoch num: 13
#
# epoch num: 14
#
# epoch num: 15

# %%
# np.save("./models/IBMmodel1tef_3", tef)

# %%
iterations = 0
for ((e_word, hin_word), value) in sorted(tef.items(), key=itemgetter(1), reverse=True):
    if iterations < 20:
        print("{:<20}{:>20.2}".format("P(%s|%s)" %(e_word, hin_word), value))
    else:
        break
    iterations += 1
# Out:
# P(रिंक|skatin)                       1.0
# P(महादेव|mahadeva)                   1.0
# P(गंगा|ganges)                      0.99
# P(राजस्थान|rajasthan)                0.99
# P(भूटान|bhutan)                     0.99
# P(भवन|bhavan)                       0.99
# P(दिल्ली|delhi)                     0.99
# P(ऐतिहासिक|historical)                0.99
# P(महादेव|mahadev)                   0.99
# P(हजार|thousand)                    0.99
# P(आज|today)                         0.99
# P(बस्तर|bastar)                     0.99
# P(पटना|patna)                       0.99
# P(मिजोरम|mizoram)                   0.99
# P(धर्मशाला|dharamshala)                0.99
# P(नेहरू|nehru)                      0.99
# P(नदी|river)                        0.99
# P(जैन|jain)                         0.98
# P(नाम|name)                         0.98
# P(बंगाल|bengal)                     0.98

# %%
predicted_eng = []
gold_eng = []

for sentence in raw_sentences_test_en:
    gold_word = sentence.split(" ")
    gold_eng.append(gold_word)

# %%
def translate_sentence(sentence, tef, file):
    '''
    takes the best translation of an hindi word
    and appends to eng sentence
    '''
    global predicted_eng
    eng_sentence = []
    print("hin:",sentence)
    
    tokens = sentence.split(" ")
    for idx, token in enumerate(tokens):
        probabilities = []
        eng_words = []
#         print("token id, token", idx, token)
        max_score = -1
        max_eng_word = ""
        for k, v in tef.items():
            if token == k[0]:
                probabilities.append(v)
                eng_words.append(k[1])
#             print(f'{k[0]} - {v}')
#         probabilities = list(tef[token].values())
#         eng_words = list(tef[token].keys())
        for tef_index, prob in enumerate(probabilities):
            if prob > max_score:
                max_score = prob
                max_eng_word = eng_words[tef_index]
        
        eng_sentence.append(max_eng_word)
        predicted_eng.append(max_eng_word)
    
    eng_sentence = " ".join(eng_sentence)
    print("eng:", eng_sentence)
    file.write(eng_sentence)
    file.write("\n")
    
    return eng_sentence

# %%
def test_model(dataset, tef):
#     tef = np.load('./models/IBMmodel1tef.npy')
    file = open("dev_translations.txt", 'w+')
    translated_data = []
    for sentence in dataset:
        translation = translate_sentence(sentence, tef, file)
        translated_data.append(translation)
    
    file.close()
    return translated_data

# %%
predicted_translations = test_model(raw_sentences_test_hi, tef)
# Out:
# hin: ताजा साँसें और चमचमाते दाँत आपके व्यक्तित्व को निखारते हैं ।
# eng: fresh skips and shimmering tooth beggar amenity shukla enhance are .
# hin: दाँतों से आपका आत्मविश्‍वास भी बढ़ता है ।
# eng: teeth from crave confidence also triglisrides is .
# hin: हमारे मसूढ़ों और दाँतों के बीच बैक्टीरिया मौजूद होते हैं ।
# eng: our initiation and teeth के beach bacteria present kalal are .
# hin: ये दाँतों को गंदा और साँसों को बदबूदार बना देते हैं ।
# eng: skiiing teeth shukla dirty and aromas shukla stinky dehradun-chakrata deduct are .
# hin: यहाँ दिए कुछ आसान नुस्खों की मदद से आप अपने दाँतों को स्वच्छ और साँसों को ताजा रख सकते हैं ।
# eng: here preached few easy prescriptions ki help from puzzles cd teeth shukla clean and aromas shukla fresh uddiyaana instantaneous are .
# hin: दाँतों को ठीक से साफ करें ।
# eng: teeth shukla alright from clean pilates .
# hin: दाँतों को ठीक से साफ करने में दो से तीन मिनट का समय लगता है ।
# eng: teeth shukla alright from clean doing in two from three minutes bhonsle time held is .
# hin: लेकिन ज्यादातर लोग इसके लिए एक मिनट से भी कम समय देते हैं ।
# eng: but mostly people creativity for one minutes from also less time deduct are .
# hin: खूब पानी पीएँ ।
# eng: aplenty water drink .
# hin: मुँह सूखने पर बैक्टीरिया हमला तेज कर देते हैं ।
# eng: mouth drying on bacteria attacked lound disgrace deduct are .
# hin: इससे साँसों से बदबू आने लगती है ।
# eng: maked aromas from chamomila coming growling is .
# hin: खूब पानी पीने से न केवल खाने के बचे - खुचे टुकड़े साफ हो जाते हैं , बल्कि लार भी बनती है ।
# eng: aplenty water drinking from neither apeej eating के chained -  chikum-3 clean occur quicker are , rather saliva also namanath is .
# hin: मुँह साफ रखने में लार की खास भूमिका होती है ।
# eng: mouth clean harbouring in saliva ki particular role sundown is .
# hin: लार उन बैक्टीरिया को नष्ट करती है जो साँसों में बदबू पैदा करते हैं ।
# eng: saliva those bacteria shukla uplifts detoxifies is which aromas in chamomila born libation are .
# hin: चबाएँ शुगर रहित चुइंग गम ।
# eng: chew sugar painless  gum .
# hin: चुइंग गम चबाने से लार बनती है ।
# eng:  gum chewing from saliva namanath is .
# hin: चुइंग गम से दाँतों को साफ रखने में मदद मिलती है ।
# eng:  gum from teeth shukla clean harbouring in help shakumbhari is .
# hin: शुगर युक्त गम को सेहत के लिए अच्छा नहीं माना जाता ।
# eng: sugar four-arm gum shukla disbeliefs के for nice not considered known .
# hin: इसलिए डेंटिस्ट शुगर युक्त गम को खाने की सलाह नहीं देते ।
# eng: therefore dentist sugar four-arm gum shukla eating ki advice not deduct .
# hin: नियमित रूप से कराएँ दाँतों की जाँच ।
# eng: regular form from podiatrist teeth ki test .
# hin: दंतचिकित्सक से दाँतों की जाँच नियमित रूप से कराएँ ।
# eng: dentist from teeth ki test regular form from podiatrist .
# hin: वे दाँतों की छोटी - मोटी समस्या को आसानी से सुलझा देते हैं ।
# eng: they teeth ki smaller - motidaman problem shukla easily from mystery deduct are .
# hin: खाने के बाद मुँह साफ करें ।
# eng: eating के after mouth clean pilates .
# hin: हर बार खाने के बाद पानी से मुँह जरूर साफ करें ।
# eng: every times eating के after water from mouth definitely clean pilates .
# hin: इससे खाने के बचे हुए टुकड़े साफ हो जाते हैं ।
# eng: maked eating के chained curvy chikum-3 clean occur quicker are .
# hin: नींबू और नमक के मिश्रण से दाँत साफ करें ।
# eng: lemon and salt के mixture from tooth clean pilates .
# hin: एक चम्मच में नमक लेकर उसमें तीन से चार बूंदें नींबू की डाल लें ।
# eng: one spoon in salt 1846 heachache three from four elixir lemon ki sprinkled grind .
# hin: हर हफ्ते इस मिश्रण से दाँतों को साफ करें ।
# eng: every fructosamine this mixture from teeth shukla clean pilates .
# hin: इससे न केवल दाँत चमचमाने लगते हैं ।
# eng: maked neither apeej tooth  progresses are .
# hin: बल्कि साँसों की दुर्गंध से भी छुटकारा मिलता है ।
# eng: rather aromas ki odour from also rid sahaj is .
# hin: सेहत है तो सब है ।
# eng: disbeliefs is then notre is .
# hin: आज की व्यस्त जिंदगी में खुद को स्वस्थ रखना किसी चुनौती से कम नहीं ।
# eng: today ki busy smoked in yourself shukla healthy rat someone challenge from less not .
# hin: लेकिन खान-पान पर ध्यान और जीवनशैली में थोड़ा बदलाव लाकर आप खुद को स्वस्थ रख सकते हैं ।
# eng: but lagging on attention and lifestyle in alchu change krishn puzzles yourself shukla healthy uddiyaana instantaneous are .
# hin: कम वसायुक्त आहार का करें सेवन ।
# eng: less  diet bhonsle pilates consumption .
# hin: खाना वही खाएँ जिसमें कम वसा और फाइबर ज्यादा हो ।
# eng: iced allurng mixer tang less fats and fiber gnerally occur .
# hin: फलों और सब्जियों में ऐसा ही अनुपात रहता है ।
# eng: fruits and vegetables in bhagirathji barhait proportion stays is .
# hin: कम वसा और फाइबर वाले खाने से वजन नियंत्रित करने में मदद मिलती है ।
# eng: less fats and fiber reptiles eating from weight controlled doing in help shakumbhari is .
# hin: कम वसा और फाइबर वाले खाने से आप कई बीमारियों से भी दूर रहते हैं ।
# eng: less fats and fiber reptiles eating from puzzles many curucmin from also away t-t are .
# hin: नमक और शराब का सेवन कम करें ।
# eng: salt and alcohol bhonsle consumption less pilates .
# hin: ब्लड प्रेशर और कोलेस्ट्राल को नियंत्रित करने के लिए नमक और शराब का सेवन कम से कम मात्रा में करें ।
# eng: creatinine pressures and poly shukla controlled doing के for salt and alcohol bhonsle consumption less from less quantity in pilates .
# hin: बंद करें धूम्रपान ।
# eng: closed pilates smoking .
# hin: धूम्रपान करने से कैंसर समेत कई बीमारियों का खतरा होता है ।
# eng: smoking doing from cancer including many curucmin bhonsle danger fibre is .
# hin: इसे छोड़ने की पूरी कोशिश करें ।
# eng: nandikeshwar jalandhara ki fulfilled attempt pilates .
# hin: रोज करें व्यायाम ।
# eng: rose pilates exercise .
# hin: अपनी रोज की दिनचर्या में व्यायाम को जरूर शामिल करें ।
# eng: endless rose ki routine in exercise shukla definitely included pilates .
# hin: नियमित व्यायाम से आप हृदय रोग , कोलन कैंसर , ब्लड प्रेशर और डायबिटीज जैसी बीमारियों से बचाव कर सकते हैं ।
# eng: regular exercise from puzzles heart disease , sewer cancer , creatinine pressures and diabetes inhibitors curucmin from prevention disgrace instantaneous are .
# hin: करते रहें हल्की - फुल्की शारीरिक गतिविधियाँ ।
# eng: libation addictions projection - certified physical ranikhola .
# hin: सीढ़ी चढ़ना , बागवानी , घर के छोटे - मोटे काम या डांस करने जैसी हल्की - फुल्की शारीरिक गतिविधियाँ जरूर करते रहें ।
# eng: ladder piling , gardening , home के younger - vague work or wenlock doing inhibitors projection - certified physical ranikhola definitely libation addictions .
# hin: इनसे शरीर में लचीलापन बना रहता है ।
# eng: stoped body in flexibility dehradun-chakrata stays is .
# hin: यदि लगातार बुखार आ रहा है तो उसकी जाँच अवश्य करायें ।
# eng: if continuously fever lustrous remained is then rajabai test definitely frofa .
# hin: मलेरिया , कालाजार , यक्ष्मा की शुरुआत बुखार से ही होती है ।
# eng: malaria ,  , pleural ki kakatia fever from barhait sundown is .
# hin: गर्मी का मौसम शुरू हो चुका है ।
# eng: heat bhonsle weather broncho occur flourished is .
# hin: बासी भोजन व सड़क किनारे बिकने वाले सामान का सेवन नहीं करें ।
# eng: stale meal riches roadsides edge heden reptiles stuff bhonsle consumption not pilates .
# hin: बच्चों को फास्ट फूड , कुरकुरे , आइसक्रीम नहीं खिलायें ।
# eng: children shukla chaat junk ,  , icecream not bael .
# hin: कै-दस्त होने पर नमक और चीनी का घोल या ओ.आर.एस पिलायें ।
# eng:  occurrence on salt and chinese bhonsle solution or  haritaki .
# hin: साफ पानी अधिक से अधिक पीयें ।
# eng: clean water greater from greater sips .
# hin: लगातार बुखार से पीड़ित हो ?
# eng: continuously fever from suffering occur ?
# hin: कालाजार , मलेरिया या फिर हाई फीवर हो सकता है ।
# eng:  , malaria or descension multi-member pericarditis occur can is .
# hin: मेरा बच्चा दस्त और बुखार दोनों पीड़ित है ?
# eng: 40-45 shrieks motions and fever both suffering is ?
# hin: पहले ओ.आर.एस. का घोल पिलायें , इसके बाद बच्चे को किसी शिशु रोग विशेषज्ञ से शीघ्र दिखायें ।
# eng: earlier o bhonsle solution haritaki , creativity after child shukla someone infant disease specialist from aches tells .
# hin: ढाई - तीन वर्षो से हर दो - तीन माह पर फीवर हो जाता है ।
# eng: jhopra - three asian from every two - three month on pericarditis occur known is .
# hin: यही नहीं जीभ पर सफेद परत जम जाती है ।
# eng: pantagan not tongue on white layer freezes critical is .
# hin: पानी की मात्रा ज्यादा लें और यूरीन कल्चर जाँच करायें ।
# eng: water ki quantity gnerally grind and  mingling test frofa .
# hin: कालाजार के प्रारंभिक लक्षण क्या हैं ?RD_PUNC
# eng:  के overspreading symptoms what are
# hin: कुछ दिनों से हल्का फीवर रहता है ।
# eng: few days from lightish pericarditis stays is .
# hin: बुखार की जाँच करें और अन्य जरूरी जाँच के पश्चात ही कालाजार प्रमाणित हो सकता है ।
# eng: fever ki test pilates and other important test के pronged barhait  certified occur can is .
# hin: मेटासिन की गोली देने से बुखार उतर जाता है और फिर 103 तक बुखार चढ़ जाता है ।
# eng:  ki pill giving from fever derails known is and descension 103 till fever 12,300 known is .
# hin: एक्सरे , टीसी-डीसी नार्मल है ।
# eng: x-ray ,  injected is .
# hin: चार - चार घंटे पर फीवर को मापें ।
# eng: four - four hours on pericarditis shukla monitering .
# hin: अगर 100 से ज्यादा फीवर हो तो पैरासीटामोल की गोली दें और किसी औषधि विशेषज्ञ चिकित्सक से परामर्श लें ।
# eng: if 100 from gnerally pericarditis occur then  ki pill let and someone medicine specialist therapist from adivsable grind .
# hin: एच.आई.वी. क्या है ?
# eng: h what is ?
# hin: यह कैसे होता है ?RD_PUNC
# eng: this how fibre is
# hin: बचाव के उपाय बताएँ ?
# eng: prevention के remedy ridges ?
# hin: यह एक प्रकार का वायरस होता है ।
# eng: this one kind bhonsle virus fibre is .
# hin: इसका फैलाव मुख्यत: असुरक्षित यौन संबंध , संक्रमित सूई , संक्रमित रक्त व माँ से बच्चों में होता है ।
# eng: baaken dispersion subsisted unsafe sexual relation , infected puncture , infected complexity riches maa from children in fibre is .
# hin: इससे शरीर की रोग प्रतिरोधक क्षमता कम होती जाती है ।
# eng: maked body ki disease resistance capacity less sundown critical is .
# hin: बोन टीवी की क्या पहचान है तथा इसका क्या इलाज है ?
# eng: chirmiya tv ki what identity is kailas baaken what treatment is ?
# hin: हड्डियों में दर्द , लगातार बुखार , भले ही यह कम क्यों न हो या बुखार शाम में बढ़ जाये , दर्द के साथ-साथ हड्डियों में विकृति आ जाये तो यह बोन टीबी का लक्षण है ।
# eng: bones in pain , continuously fever , might barhait this less why neither occur or fever evening in cylicia-30 cedrone , pain के hommocystin bones in deformity lustrous cedrone then this chirmiya tb bhonsle symptoms is .
# hin: इससे हड्डियाँ कमजोर हो जाती हैं और गलने लगती हैं ।
# eng: maked brittle weak occur critical are and degenerating growling are .
# hin: इस परिस्थिति में लकवा भी मार सकता है ।
# eng: this stupid in paralysis also mar can is .
# hin: इसकी जाँच के लिए डिजिटल एक्सरे , एम.आर.आई. करायें , टीबी की दवा एक वर्ष तक लें एवं विशेषज्ञ चिकित्सक से परामर्श लें ।
# eng: 2999 test के for digital x-ray , radiations frofa , tb ki dava one 2003-2004 till grind stalagmite specialist therapist from adivsable grind .
# hin: रात में सोते समय शरीर पर एक चादर जरूर रखे एवं पंखा कम से कम चलायें ।
# eng: night in bedtime time body on one sheet definitely life-size stalagmite fan less from less  .
# hin: इससे अगर अपने आप सही महसूस नहीं करते हैं तो एन्टीएलर्जिक टेबलेट दस दिनों तक लें ।
# eng: maked if cd puzzles correct feel not libation are then  tablet ten days till grind .
# hin: बच्चों को घमौंरी हो रही है क्या करें ?
# eng: children shukla  occur proving is what pilates ?
# hin: डायरिया का घरेलू उपचार क्या है ?
# eng: diarrhoea bhonsle domestic treatment what is ?
# hin: एक गिलास पानी में दो चम्मच चीनी एवं एक चुटकी नमक डालकर उबालकर दें ।
# eng: one glasses water in two spoon chinese stalagmite one pinch salt adding boiling let .
# hin: धूप के कारण क्या कालाजार रोग होता है ?
# eng: sunlight के cause what  disease fibre is ?
# hin: क्या गर्मी में इसका प्रकोप बढ़ जाता है ?
# eng: what heat in baaken outburst cylicia-30 known is ?
# hin: कालाजार बालू मक्खी के काटने से होता है ।
# eng:  sand fly के biting from fibre is .
# hin: इसका उपचार सभी अस्पतालों में है ।
# eng: baaken treatment everyone hospitals in is .
# hin: इसके लिए अब टेबलेट भी उपलब्ध हैं ।
# eng: creativity for now tablet also available are .
# hin: किसी बच्चे को कुकुर खाँसी हो जाये तो क्या करना चाहिये ?
# eng: someone child shukla infectious cough occur cedrone then what diffucult wiped ?
# hin: बच्चे को डीपीटी का टीका लगायें ।
# eng: child shukla dpt bhonsle vaccine kurmasana .
# hin: किसी विशेषज्ञ चिकित्सक से दिखायें तथा खाँसी के लिए बलगम की जाँच करायें ।
# eng: someone specialist therapist from tells kailas cough के for phlegm ki test frofa .
# hin: अपनी आँखों की देखभाल को लेकर आप कितने जागरूक हैं ?
# eng: endless eyes ki care shukla 1846 puzzles panchmandir conscious are ?
# hin: हर छह माह में करें आँखों की जाँच ।
# eng: every six month in pilates eyes ki test .
# hin: चश्मे या कांटैक्ट लेंस का रखरखाव करें ।
# eng: maji or  lens bhonsle neurotrophic pilates .
# hin: नियमित आँखें धोना ।
# eng: regular syes disinfectant .
# hin: लेकिन इन सबके साथ अगर आप अपने खान -|RD_PUNC पान पर थोड़ा सा ध्यान दें ।
# eng: but inn jktdc alongside if puzzles cd khan  betel on alchu chatham attention let .
# hin: तो न सिर्फ आपकी आँखों की रोशनी बेहतर हो सकती है ।
# eng: then neither triple undestand eyes ki light better occur assimilated is .
# hin: लेकिन 12 - 15 सीटों वाला यह टिवन ओटर प्लेन मालदीव जैसे आर्कीपेलेगो ( द्वीप समूह ) को घूमने के लिए निर्विवाद रूप से श्रेष्‍ठ है ।
# eng: but 12 - 15 seats wala this   plane maldives like  -rrb- island group -rrb- shukla roaming के for indisputable form from esteemed is .
# hin: पानी की सतह पर स्पीड बोट की तरह दौड़ते हुए यह कब हवा में उठ जाता है , पता नहीं चलता ।
# eng: water ki surface on mph boat ki unlike  curvy this explode breeze in crashing known is , detected not runs .
# hin: पूरी उड़ान में आपको आम हवाई जहाजों की उड़ान का अनुभव नहीं होता ।
# eng: fulfilled flight in himslef aam airports ships ki flight bhonsle experience not fibre .
# hin: हर वक्‍त आपकी निगाहें खिड़की से नीचे को ताकती रहती हैं - मालदीव के अलग-अलग शेड्‍स के नीले पानी में रिजॉर्ट द्वीपों व कोरल द्वीपों को निहारते हुए ।
# eng: every falsafa undestand preying window from below shukla  kunain are - maldives के unhyegenic shades के blue water in resorts isles riches coral isles shukla appreciating curvy .
# hin: सब कुछ कितना साफ दिखता है ।
# eng: notre few muktidhaam clean 760 is .
# hin: मालदीव में दो ही सी प्लेन कंपनियाँ हैं ।
# eng: maldives in two barhait c plane companies are .
# hin: ट्राँस मालदीवियन इन्हीं में से एक है जिसके पास बीस सी प्लेन है ।
# eng:   pigments in from one is havankunda aalam twenty c plane is .
# hin: आप चाहें तो लगभग चार हजार रुपये ( प्रति व्यक्‍ति ) में घंटेभर की हवाई सैर कर सकते हैं या फिर पूरा सी प्लेन अपनी दिनभर की तफरीह के लिए किराये पर ले सकते हैं ( बशर्ते जेब गहरी हो ) ।
# eng: bazaar ki vadpradaka stroll from reverted cd cruise on going के for  ki baagmati returning curvy , when preying involuntarily sarak के hommocystin alchu imbibe के water in scanning then acknowledges happened that here के people this beautifully ki price frss extent till inapproachability are .
# hin: पानी इतना साफ था कि लैंपपोस्ट की रोशनी में नीचे कई मीटर गहराई में तैरती मछलियाँ अपने सारे रंगों के साथ दिखाई दे रही थीं ।
# eng: water remedial clean was that  ki light in below many metres depth in floating fishes cd dockyards colors के alongside visible chati proving mrigthuni .
# hin: यह समंदर का वो हिस्सा था जो शहर से एकदम सटा हुआ था ।
# eng: this imbibe bhonsle stilt portion was which city from absolutely parkota happened was .
# hin: आप भारत के किसी शहर से सटे हुए समुद्र या नदी के पानी में कुछ सेंटीमीटर भी साफ देख सकें तो खुद को खुशकिस्मत पाएँगे ।
# eng: puzzles india के someone city from gonda curvy samudra or river के water in few centimeters also clean thangka premenopausal then yourself shukla  lovable .
# hin: एमवी एक्वामैरिन पर लौटते हुए माले में बिताए हुए शाम के दो घंटे जेहन में घूम रहे थे ।
# eng:   on returning curvy  in availed curvy evening के two hours conscience in ramble constables were .
# hin: कोरल रीफ ( मूँगा चट्‍टानें ) यहाँ का जीवन हैं ।
# eng: coral reef -rrb- reefs 12,000 -rrb- here bhonsle life are .
# hin: यहाँ तक की आपको कब्रों पर लगे पत्थरों पर भी मूँगा चट्‍टानें मिल जाएँगी ।
# eng: here till ki himslef sultanunnisa on tempt stones on also reefs 12,000 mill cabs .
# hin: राष्‍ट्रपति नाशीद का भाषण सुनने के कुछ देर पहले हम उनके सरकारी आवास के बाहर खड़े थे ।
# eng: president  bhonsle speech hearing के few late earlier we gompas governmnet accommodation के outside staright were .
# hin: यकीन नहीं होता था कि हम किसी देश की सर्वोच्च शख्सियत के आवास के आगे थे , दूर-दूर तक कोई सुरक्षाकर्मी नहीं था ।
# eng: ultimately not fibre was that we someone country ki punsu  के accommodation के ahead were , panormic till distracts scour not was .
# hin: मजे से हम उसके बंगले के दरवाजे से अंदर हाथ बढ़ाकर महज पचास मीटर दूर बगीचे व बरामदे के फोटो खींच रहे थे ।
# eng: joyfully from we lohaganj bungalows के darwaza from underwater hand comprehension mere fifty metres away gardens riches balconies के photos draws constables were .
# hin: क्या आप भारत में किसी अदने से नेता के घर के बारे में ऐसा सोच सकते हैं ?
# eng: what puzzles india in someone jayarambati from leader के home के about in bhagirathji thinking instantaneous are ?
# hin: पता तो यह भी चला कि राष्‍ट्रपति कभी - कभार पैदल ही सड़कें पार करते हुए दो ब्लॉक आगे अपने दफ्तर में पहुँच जाते हैं ।
# eng: detected then this also tusk that president ever - पेरोजिस्म pedistrian barhait roads crossing libation curvy two block ahead cd rajpath in accessibility quicker are .
# hin: मालदीव के बारे में हर बात अभिभूत करने वाली थी ।
# eng: maldives के about in every thing ramcharita doing yumthangchu 242 .
# hin: इसीलिए मुझे अगले दिन का बेसब्री से इंतजार था ।
# hin: कई बार तो लगा कि अब गिरे ।
# eng: many times then bugji that now pans .
# hin: किसी तरह सुबह 8 बजे गजरौला पहुँचे ।
# eng: someone unlike morning 8 o'clock gajraula banka .
# hin: खैर हम 12 बजे रामनगर पहुँच गए ।
# eng: khair we 12 o'clock raamnagar accessibility went .
# hin: कार्बेट पार्क रामनगर से 20 किलोमीटर आगे है ।
# eng: corbett park raamnagar from 20 kilometers ahead is .
# hin: हमारा रिजॉर्ट पार्क के नजदीक ढिकुली में था , जिसकी बुकिंग हमने पहले ही करवा दी थी ।
# eng: intractable resorts park के balvan  in was , 965 booking underestimated earlier barhait undergone sharbari 242 .
# hin: उस दिन कुछ खास कार्यक्रम था नहीं हम ठंड होने के बावजूद पहले कोसी के किनारे घूमने गए ।
# eng: vadpradaka day few particular program was not we coldness occurrence के spite earlier kosi के edge roaming went .
# hin: दो - तीन घंटे वहाँ बिताने के बाद हम कार्बेट म्यूजियम निकल गए , जो बड़ी मुश्‍किल 2 किमी दूर धांगड़ी गेट के नजदीक था ।
# eng: two - three hours therefrom spending के after we corbett rajwada matera went , which conveniently drooling 2 793 away  gate के balvan was .
# hin: वहाँ से हम नीचे रामनगर घूमने चले गए ।
# eng: therefrom from we below raamnagar roaming usrain went .
# hin: लौटते देर शाम हो गई ।
# eng: returning late evening occur scanning .
# hin: दिल्ली से ठान कर निकला था कि जंगल में छुट्‍टा घूमता शेर जरूर देखूँगा तो पूरी रात सपने में मुझे शेर दिखाई देते रहे ।
# eng: delhi from approved disgrace skimmed was that jungle in  rotated lion definitely  then fulfilled night dreams in me lion visible deduct constables .
# hin: रात की गहराइयों के बीच अचानक मुझे जबरदस्त दहाड़ सुनाई दी और उसके बाद तो जो कुत्तों ने भौंकना शुरू किया तो दो घंटे तक थमे नहीं ।
# eng: night ki infinitive के beach suddenly me overbearing footprints heard sharbari and lohaganj after then which dogs researcher  broncho veda then two hours till  not .
# hin: लिहाजा पहले कालाढुंगी और कार्बेट फॉल घूमने का सुझाव आया ।
# eng: countless earlier  and corbett jonha roaming bhonsle suggestion baghal .
# hin: कालाढुंगी तीस किमी दूर है , जबकि कार्बेट फॉल रास्ते में पड़ता है ।
# eng:  thirty 793 away is , whereas corbett jonha tripal in varnigad is .
# hin: कालाढुंगी में जिम कार्बेट साहब का म्यूजियम है , जहाँ उनकी निजी जिंदगी से जुड़ी कुछ अहम चीजें रखी हैं ।
# eng:  in gym corbett sahab bhonsle rajwada is , where dashrath private smoked from rumors few virangana things neelam are .
# hin: लौटते-लौटते साढ़े बारह बज गए ।
# eng:  pataka twelve rung went .
# hin: कालाढुंगी बेहद खूबसूरत जगह है , जिम कार्बेट इसी गाँब में आकर बसे थे ।
# eng:  abovementioned beautiful space is , gym corbett similarly  in mingles nestled were .
# hin: रिजॉर्ट पहुँचने पर सफारी जिप्सी हमारा इंतजार कर रही थी ।
# eng: resorts reaching on safari gypsy intractable wait disgrace proving 242 .
# hin: बताया गया कि उन्होंने वहाँ की नंबर एक साइट बिजरानी में साइटिंग की व्यवस्था कराई है ।
# eng: told sutra that sideline therefrom ki finance one site  in  ki arrangement karai is .
# hin: नंबर एक के बारे में पूछने पर बताया कि वहाँ ग्रासलैंड ज्यादा है और टाइगर इस दौरान ठंड से बचने के लिए उसी तरफ आते हैं ।
# eng: finance one के about in inquire on told that therefrom  gnerally is and tiger this during coldness from escape के for coupe baagmati come are .
# hin: बिजरानी पहुँचते ही हमें एक गाइड दिया गया , जो चार घंटे घुमाने के ढाई सौ रुपये लेता है ।
# eng:  headphone barhait us one guide gave sutra , which four hours pairs के jhopra hundred rupees soaks is .
# hin: हम अंदर जंगल के लिए रवाना हो गए ।
# eng: we underwater jungle के for ustoli occur went .
# hin: हमने वहाँ कई तरह के जानवर और हिरनों की कई प्रजातियाँ देखीं ।
# eng: underestimated therefrom many unlike के wolf and flock ki many species canons .
# hin: अंदर हमने दो टस्कर हाथी देखे , जिनके लंबे-लंबे दाँत थे ।
# eng: underwater underestimated two  elephant fires , benefitial murmuring tooth were .
# hin: मैंने जमकर फोटोग्राफी की ।
# eng: threw solidifies photography ki .
# hin: इस बीच गाइड ने टाइगर को ट्रैक करना शुरू कर दिया ।
# eng: this beach guide researcher tiger shukla falot diffucult broncho disgrace gave .
# hin: गाइड ने बताया कि पार्क में तकरीबन 150 के आस-पास ही टाइगर हैं , जिनमें से हाल ही में कुछ मर चुके हैं ।
# eng: guide researcher told that park in keshodh 150 के anua barhait tiger are , traits from recent barhait in few die glacial are .
# hin: कई जगह हमें उनके पंजों के निशान भी दिखे , लेकिन टाइगर का दर्शन न मिलने से मैं उदास था ।
# eng: many space us gompas claws के paw also unhappy , but tiger bhonsle darshan neither ideology from i sad was .
# hin: तीसरे दिन हमें दिल्ली लौटना था ।
# eng: third day us delhi halfway was .
# hin: मेरे दिमाग में तो टाइगर का फितूर सवार था ।
# eng: me membranes in then tiger bhonsle  riding was .
# hin: तभी मुझे हल्द्वानी के अपने एक पुराने मित्र की याद आई ।
# eng: mundamaladanga me haldwani के cd one olden friend ki remember liner .
# hin: मैंने उसे ऐसे ही फोन लगा दिया ।
# eng: threw him such barhait phones bugji gave .
# hin: मैंने उसे बताया कि मैं कार्बेट आया हुआ हूँ ।
# eng: threw him told that i corbett baghal happened am .
# hin: उसने पूछा टाइगर देखा या नहीं ।
# eng: replied asked tiger thrumsingla or not .
# hin: उसके यह शब्द तीर की तरह चुभ गए ।
# eng: lohaganj this word arrow ki unlike pins went .
# hin: मैंने धीरे से कहा , नहीं ।
# eng: threw hoist from said , not .
# hin: पार्क में बाइक ले जाने की अनुमति नहीं थी ।
# eng: park in bike jacuzzi going ki permission not 242 .
# hin: हमें किसी ने सलाह दी कि आप अंदर के लिए सफारी ले लो ।
# eng: us someone researcher advice sharbari that puzzles underwater के for safari jacuzzi low .
# hin:
# eng:

# %%
# def find_recall_precision(predicted_translations):
#     y_pred = list(predicted_translations)
#     y_true = gold_eng
#     r = recall(y_true, y_pred)
#     p = precision(y_true, y_pred)
#     return r, p;

# %%
# r, p = find_recall_precision(predicted_eng)
# print("recall:",r,"\n", "precision:", p)
